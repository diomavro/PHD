# %%
import networkx as nx
from matplotlib import pyplot as plt

# %%
#DiGraph makes directed graph
G = nx.DiGraph()
#We create the nodes
G.add_nodes_from([1,2,3])
#We create the arrows from node to node
G.add_edges_from([(1,2),(1,3),(2,3)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()

# %%
G = nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(3,4),(4,5),(2,5)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()

# %%
G = nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(3,4),(4,5),(2,5),(1,4)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()

# %%
G = nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(3,4),(4,5),(2,5),(2,4)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()

# %%
G = nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,3),(3,2),(1,4),(4,5),(2,5),(2,4)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()

# %%
G = nx.DiGraph()
G.add_nodes_from([1,2,3,4,5])
G.add_edges_from([(1,2),(1,3),(3,5),(3,4),(5,4),(2,5),(4,2)])

plt.tight_layout()
nx.draw_networkx(G, arrows=True)
# tell matplotlib you're done with the plot: https://stackoverflow.com/questions/741877/how-do-i-tell-matplotlib-that-i-am-done-with-a-plot
plt.show()
