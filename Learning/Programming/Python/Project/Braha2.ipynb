# %% [markdown]
# $$\kappa = \frac{<k^2>}{<k>}=2$$
#
# If this above is above 2 then you have a giant component that is non-0. Degree corrolation can be neglected.
# Because the variance of the degree distribution is the same as the average of the degree.
#
# $$<k^2>=<k^2>-<k>^2 $$
#
# $$<k^2> = <k>(<k>+1) $$
#
# Therefore the kappa is $$=2 $$
#
# # Fragility
#
# How much can you survive attacks? You need to calculate the new kappa and infer the p that would destroy it.
# Mean field argument says that actually if we look at a neighborhood and apply the p we can use.
#
# $$\kappa = \frac{<k_{in}k_{out}>}{<k>}=1 $$
#
# So if we have $$p(k) \approx k^{-\gamma} $$
# $$2<\gamma<3 $$
# $$ \kappa_0 = \infty $$
#
# Ultra robustness. Because the critical p_{critical} is 1 this makes networks ultra.
#
# Remember that as gamma becomes smaller, the longer is the tail.
#
# # SIS model
# This model has two categories, infective and susceptible individuals.  $$\delta $$ is the rate of recovery and $$\beta$$ is the rate of infection. If we assume that the network is completely random then...
#
# In the rate equation you have the number of people, N, the number of Infected, I, etc. So if
#
# For general topology:
# The coefficient of variation is: $$C_v^2 = \frac{\sigma^2}{<k>^2}$$
# So you get Kappa on slide 241
# Therefore the disease will always spread on scale free networks.
#
# We assume that the corrolation between neighbors is 0 however the corrolation between in and out is not 0.
# $$cov(x,y)=<xy>-<x><y>$$
# $$\rho_{x,y}= \frac{cov(x,y)}{\sigma_x \sigma_y}$$
# $$<k_{in}>=<k_{out}>=<k>$$
#
# # Robustness in a dynamical process
#
# He starts with a prisoners dillema game?
#
# cov(x,x)=\sigma^2_x
#
# The variance is important for undirected network and the covariance is important for the directed network.
#
# the network topology(second moment divided by the first) and the parameters of the system.
#
# Each node in the network is assigned to a strategy.
#
# $$-\delta p = p_y - p_x$$
#
# $$p(imitation) = \frac{1}{1+e^{-\delta p}}$$
#
# How do you create a network which has the same degree distribution but with no corrolation between neighbors? You need to create an ensemble of networks that has no such corrolation. Remember that the clustering coefficient is much higher on the real than the random model. Why should we need not just immitate the average degree with a random graph? Because we have killed the distribution of the real network. To properly transform the network without killing the degree distribution:
#
# you choose a pair of links and switch them randomly.
# If this has an effect then it must be that the corrolation of the degree distribution has an effect.
#
# # Centrality
# Degree is one measure
# If it easily accessible(close to all other nodes)
# Or if it lies on many shortest paths
#
# There is the absolute degree of centrality
# There is the relative degree of centrality, this one compares the highest degree relative to the highest possible degree in the network.
#
# Google algorithm is a vector of type of centrality for each node.
# Rank centrality of 1 must be the sum of the rank centrality of the others plus 1 over lambda. en
