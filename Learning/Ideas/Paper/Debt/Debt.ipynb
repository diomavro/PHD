# %%
pip install mesa
# Out:
# Collecting mesa
#   Downloading https://files.pythonhosted.org/packages/cc/b7/5bde310fcbb82d7741ce74fa171892a7d4599a719b5e8373f38a7e66d8fc/Mesa-0.8.7-py3-none-any.whl (648kB)
# Requirement already satisfied: pandas in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (0.24.2)
# Requirement already satisfied: tqdm in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (4.31.1)
# Collecting cookiecutter (from mesa)
#   Downloading https://files.pythonhosted.org/packages/95/83/83ebf950ec99b02c61719ccb116462844ba2e873df7c4d40afc962494312/cookiecutter-1.7.2-py2.py3-none-any.whl
# Requirement already satisfied: networkx in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (2.2)
# Requirement already satisfied: click in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (7.0)
# Requirement already satisfied: tornado in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (6.0.2)
# Requirement already satisfied: numpy in c:\users\davidettinger02\anaconda3\lib\site-packages (from mesa) (1.16.2)
# Requirement already satisfied: pytz>=2011k in c:\users\davidettinger02\anaconda3\lib\site-packages (from pandas->mesa) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\davidettinger02\anaconda3\lib\site-packages (from pandas->mesa) (2.8.0)
# Requirement already satisfied: six>=1.10 in c:\users\davidettinger02\anaconda3\lib\site-packages (from cookiecutter->mesa) (1.12.0)
# Collecting requests>=2.23.0 (from cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
# Requirement already satisfied: MarkupSafe<2.0.0 in c:\users\davidettinger02\anaconda3\lib\site-packages (from cookiecutter->mesa) (1.1.1)
# Collecting poyo>=0.5.0 (from cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/42/50/0b0820601bde2eda403f47b9a4a1f270098ed0dd4c00c443d883164bdccc/poyo-0.5.0-py2.py3-none-any.whl
# Collecting binaryornot>=0.4.4 (from cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/24/7e/f7b6f453e6481d1e233540262ccbfcf89adcd43606f44a028d7f5fae5eb2/binaryornot-0.4.4-py2.py3-none-any.whl
# Collecting jinja2-time>=0.2.0 (from cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/6a/a1/d44fa38306ffa34a7e1af09632b158e13ec89670ce491f8a15af3ebcb4e4/jinja2_time-0.2.0-py2.py3-none-any.whl
# Collecting python-slugify>=4.0.0 (from cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/92/5f/7b84a0bba8a0fdd50c046f8b57dcf179dc16237ad33446079b7c484de04c/python-slugify-4.0.0.tar.gz
# Requirement already satisfied: Jinja2<3.0.0 in c:\users\davidettinger02\anaconda3\lib\site-packages (from cookiecutter->mesa) (2.10)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\davidettinger02\anaconda3\lib\site-packages (from networkx->mesa) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\davidettinger02\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\davidettinger02\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2019.3.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\davidettinger02\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\davidettinger02\anaconda3\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (1.24.1)
# Collecting arrow (from jinja2-time>=0.2.0->cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/99/b5/1f1c5ef3156f7b514c58613fe56e5670dc56374ab744bd1eb653c95e16b5/arrow-0.15.6-py2.py3-none-any.whl (47kB)
# Collecting text-unidecode>=1.3 (from python-slugify>=4.0.0->cookiecutter->mesa)
#   Downloading https://files.pythonhosted.org/packages/a6/a5/c0b6468d3824fe3fde30dbb5e1f687b291608f9473681bbf7dabbf5a87d7/text_unidecode-1.3-py2.py3-none-any.whl (78kB)
# Building wheels for collected packages: python-slugify
#   Building wheel for python-slugify (setup.py): started
#   Building wheel for python-slugify (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\DavidEttinger02\AppData\Local\pip\Cache\wheels\11\94\81\312969455540cb0e6a773e5d68a73c14128bfdfd4a7969bb4f
# Successfully built python-slugify
# Installing collected packages: requests, poyo, binaryornot, arrow, jinja2-time, text-unidecode, python-slugify, cookiecutter, mesa
#   Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
# Successfully installed arrow-0.15.6 binaryornot-0.4.4 cookiecutter-1.7.2 jinja2-time-0.2.0 mesa-0.8.7 poyo-0.5.0 python-slugify-4.0.0 requests-2.23.0 text-unidecode-1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return 1 + (1 / N) - 2 * B


class BoltzmannWealthModel(Model):
    """A simple model of an economy where agents exchange currency at random.
    All the agents begin with one unit of currency, and each time step can give
    a unit of currency to another agent. Note how, over time, this produces a
    highly skewed distribution of wealth.
    """

    def __init__(self, N=100, width=10, height=10):
        self.num_agents = N
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini}, agent_reporters={"Wealth": "wealth"}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = self.random.randrange(self.grid.width)
            y = self.random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

        self.running = True
        self.datacollector.collect(self)

    def step(self):
        self.schedule.step()
        # collect data
        self.datacollector.collect(self)

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""

    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = self.random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = self.random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-0491d24d3aa1> in <module>
# ----> 1 from mesa import Agent, Model
#       2 from mesa.time import RandomActivation
#       3 from mesa.space import MultiGrid
#       4 from mesa.datacollection import DataCollector
#       5
#
# ModuleNotFoundError: No module named 'mesa'

# %%
# https://worthwhile.typepad.com/worthwhile_canadian_initi/2011/12/debt-is-too-a-burden-on-our-children-unless-you-believe-in-ricardian-equivalence.html
    
# https://twitter.com/MacRoweNick/status/1181546892775301121
        
# https://twitter.com/MacRoweNick/status/1181559229678784512

# https://towardsdatascience.com/introduction-to-mesa-agent-based-modeling-in-python-bcb0596e1c9a

# https://python-advanced.quantecon.org/amss3.html
