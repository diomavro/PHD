# %%
Some class of agents
    productivity
    wealth
    preferences
    age
    health
    alive
    male

generate agents
    number and characteristics
    
taxescollected = income taxes paid

year passes:
    count number of agents
    newagents some function of number of agents

work and taxation
for each agent
    if age > 2
        alive = false
    if alive: true 
    age+1
    work
    money is some function of work
    incometaxespaid=money*tax
    taxescollected =+ incometaxespaid
    wealth = wealth + money - incometaxes paid

for each agent 
    wealth = taxescollected+
    taxescollected/divided number of agents 
    
compute average age, average health

plotagentwealth distribution

# %%
# Classes

class Agent(object):
    def __init__(self, identification, productivity, wealth, preferences, age, health, alive, sex):
        self.identification = identification
        self.productivity = productivity
        self.wealth = wealth
        self.preferences = preferences
        self.age = age
        self.health = health
        self.alive = alive
        self.sex = sex
    def description(self):
        print("My id is", self.identification)
#     print("My productivity is", self.productivity)
        print("My wealth is", self.wealth)
#     print("My preferences is", self.preferences)
        print("My age is", self.age)
#     print("My health is", self.health)
#     print("My alive is", self.alive)
#     print("My sex is", self.sex)
    def work(self):
        output = self.productivity*10
        return output
    
    def calcutility(self):
        utility = self.wealth*5
        if utility>10:
            print("I'm good")
        else:
            print("Need more") 

def Create_agents():
    global id
    alive.append(Agent(id,100.0,20,"blue",30,0,True,True ))
    id += 1
    
# functions
def Initialize():
    for x in range(3):
        Create_agents()
    
def Death():
    temp = alive.copy()
    for agent in temp:
        if agent.age>30:
            agent.alive = False
            print("Death of", agent.identification)
            dead.append(agent)
            alive.remove(agent)
            
def Time_skip(): 
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%SKIPPING TIME%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")    
    global year
    year += 1
    print("The new year is", year)
    for agent in alive:
        agent.age +=1
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%Computing babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
    babies = len(alive)
    print(babies)
    for x in range(babies):
        Create_agents()
    print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%End of babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")    
    for agent in alive:
        global taxescollected
        taxescollected += agent.work()*(taxrate)
        agent.wealth += agent.work()*(1-taxrate)
    Death()
        
# Values
taxescollected = 0
alive = []
dead = []
id = 0
year = 0
taxrate = .50

Initialize()

# Testing
for agent in alive: 
    agent.description()
    
Time_skip()

for agent in alive: 
    agent.description()
print(taxescollected)
# Out:
# My id is 0
# My wealth is 20
# My age is 30
# My id is 1
# My wealth is 20
# My age is 30
# My id is 2
# My wealth is 20
# My age is 30
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%SKIPPING TIME%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# The new year is 1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%Computing babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# 3
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%End of babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Death of 0
# Death of 1
# Death of 2
# My id is 3
# My wealth is 520.0
# My age is 30
# My id is 4
# My wealth is 520.0
# My age is 30
# My id is 5
# My wealth is 520.0
# My age is 30
# 3000.0

# %%
class Agent:
    def __init__(self, identification, productivity, wealth, preferences, age, health, alive, sex):
        self.identification = identification
        self.productivity = productivity
        self.wealth = wealth
        self.preferences = preferences
        self.age = age
        self.health = health
        self.alive = alive
        self.sex = sex

    def description(self):
        print("My id is", self.identification)
        print("My age is", self.age)
        print("My wealth is", self.wealth)
        
    def work(self):
        output = self.productivity*10
        print("I made", output)
        return output


class Simulation:
    def __init__(self):
        self.alive = []
        self.dead = []
        self._id = 0
        self.year = 0
        self.taxrate = 0.1
        self.taxescollected = 0

    def create_agent(self):
        self.alive.append(Agent(self._id, 100, 20, "blue", 0, 0, True, True))
        self._id += 1

    def deaths(self):
        for agent in self.alive.copy():
            if agent.age > 1:
                agent.alive = False
                print("Death of", agent.identification)
                self.taxescollected += agent.wealth
                print("Taxed the dead", self.taxescollected)
                self.dead.append(agent)
                self.alive.remove(agent)
                
    def taxation(self):
        for agent in self.alive:
            self.taxescollected += agent.work()*(self.taxrate)
            print("Taxes collected", self.taxescollected)
            agent.wealth += agent.work()*(1-self.taxrate)
            print("My wealth is", agent.wealth)
    
    def calculatebirths(self):
        babies = int(len(alive)/8)
        return babies    

    def time_skip(self):
        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%SKIPPING TIME%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
        self.year += 1
        print("The new year is", self.year)
        for agent in self.alive:
            agent.age += 1
        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%Computing babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
        for x in range(self.calculatebirths()):
            self.create_agent()
        print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%End of babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")    
        self.taxation()
        self.deaths()

if __name__ == '__main__':
    simulation = Simulation()
    for _ in range(3):
        simulation.create_agent()

    # Testing
    for agent in simulation.alive: 
        agent.description()

    simulation.time_skip()
    simulation.time_skip()

    for agent in simulation.alive: 
        agent.description()
    print(taxescollected)
# Out:
# My id is 0
# My age is 0
# My wealth is 20
# My id is 1
# My age is 0
# My wealth is 20
# My id is 2
# My age is 0
# My wealth is 20
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%SKIPPING TIME%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# The new year is 1
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%Computing babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%End of babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# I made 1000
# Taxes collected 100.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 200.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 300.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 400.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 500.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 600.0
# I made 1000
# My wealth is 920.0
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%SKIPPING TIME%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# The new year is 2
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%Computing babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%End of babies%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# I made 1000
# Taxes collected 700.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 800.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 900.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 1000.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 1100.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 1200.0
# I made 1000
# My wealth is 1820.0
# I made 1000
# Taxes collected 1300.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 1400.0
# I made 1000
# My wealth is 920.0
# I made 1000
# Taxes collected 1500.0
# I made 1000
# My wealth is 920.0
# Death of 0
# Taxed the dead 3320.0
# Death of 1
# Taxed the dead 5140.0
# Death of 2
# Taxed the dead 6960.0
# My id is 3
# My age is 1
# My wealth is 1820.0
# My id is 4
# My age is 1
# My wealth is 1820.0
# My id is 5
# My age is 1
# My wealth is 1820.0
# My id is 6
# My age is 0
# My wealth is 920.0
# My id is 7
# My age is 0
# My wealth is 920.0
# My id is 8
# My age is 0
# My wealth is 920.0
# 25500.0

# %%
len(alive)
# Out:
# 1
